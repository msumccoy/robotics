# %% [markdown]
# # Install Dependencies

# %%
# !pip install gym;
# !pip install keras-rl2;
# Out:
# Requirement already satisfied: gym in g:\miniconda3\envs\tensorflow\lib\site-packages (0.21.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from gym) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from gym) (1.19.5)
# Requirement already satisfied: keras-rl2 in g:\miniconda3\envs\tensorflow\lib\site-packages (1.0.5)
# Requirement already satisfied: tensorflow in g:\miniconda3\envs\tensorflow\lib\site-packages (from keras-rl2) (2.6.0)
# Requirement already satisfied: six~=1.15.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (1.15.0)
# Requirement already satisfied: clang~=5.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (5.0)
# Requirement already satisfied: h5py~=3.1.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (3.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (1.12.1)
# Requirement already satisfied: keras~=2.6 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (2.6.0)
# Requirement already satisfied: numpy~=1.19.2 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (1.19.5)
# Requirement already satisfied: absl-py~=0.10 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (0.14.1)
# Requirement already satisfied: gast==0.4.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (0.4.0)
# Requirement already satisfied: termcolor~=1.1.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (1.1.0)
# Requirement already satisfied: wheel~=0.35 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (0.37.0)
# Requirement already satisfied: google-pasta~=0.2 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (3.7.4.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (1.1.2)
# Requirement already satisfied: protobuf>=3.9.2 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (3.18.1)
# Requirement already satisfied: tensorflow-estimator~=2.6 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (2.6.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: tensorboard~=2.6 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (2.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow->keras-rl2) (1.41.0)
# Requirement already satisfied: markdown>=2.6.8 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (1.8.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.3.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.26.0)
# Requirement already satisfied: setuptools>=41.0.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (58.0.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in g:\miniconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.0.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in g:\miniconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in g:\miniconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->keras-rl2) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in g:\miniconda3\envs\tensorflow\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in g:\miniconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in g:\miniconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in g:\miniconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in g:\miniconda3\envs\tensorflow\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->keras-rl2) (3.1.1)

# %% [markdown]
# # Test environment with OpenAI Gym

# %%
from gym import Env
from gym.spaces import Discrete, Box
import numpy as np
import random
import time

import sim_master
# Out:
# pygame 2.0.2 (SDL 2.0.16, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
sim = sim_master.SimMaster()
states = sim.frame_step(np.array([0,0,15,0,0]))
print(states)
print("\n\n")
for i in range(100):
    states = sim.frame_step(np.array([0,0,0,0,1]))
    print(states)
    print("\n\n")
    time.sleep(0.1)
    

states = sim.frame_step(np.array([0,6,15,0,0]))
print(states)
print("\n\n")
for i in range(100):
    states = sim.frame_step(np.array([0,0,0,0,1]))
    print(states)
    print("\n\n")
    time.sleep(0.1)
    
states = sim.frame_step(np.array([0,6,15,0,0]))
print(states)
print("\n\n")
for i in range(100):
    states = sim.frame_step(np.array([0,0,0,0,1]))
    print(states)
    print("\n\n")
#     time.sleep(0.1)
    
    
states = sim.frame_step(np.array([0,6,15,0,0]))
print(states)
print("\n\n")
for i in range(100):
    states = sim.frame_step(np.array([0,0,0,0,1]))
    print(states)
    print("\n\n")
#     time.sleep(0.1)
    
sim.exit()
# Out:
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 3.33333333e-02
#  0.00000000e+00 0.00000000e+00 1.50000000e+01 0.00000000e+00
#  0.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 6.66666667e-02
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 1.00000000e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 1.33333333e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 1.66666667e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 2.00000000e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 2.33333333e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 2.66666667e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 3.00000000e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 3.33333333e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 3.66666667e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 4.00000000e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 4.33333333e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [2.03000000e+02 2.88000000e+02 1.00000000e+00 1.06763557e+01
#  2.48298208e+02 1.73717508e+02 1.09658561e+02 1.40002548e+00
#  4.91146618e+02 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 4.66666667e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00]
#
#
#
# [203.         288.           1.          10.67635568 248.29820781
#  173.71750791 109.658561     1.40002548 491.14661762   0.
#    0.           1.           1.           0.           0.
#    0.5          0.           0.           0.           0.
#    1.        ]
#
#
#
# [208.         288.           1.          10.89441839 243.38652387
#  173.99099404 114.62983905   1.41442321 486.14812557   0.
#    0.           0.           1.           1.           0.
#    0.53333333   0.           0.           0.           0.
#    1.        ]
#
#
#
#
            distance --> 0 to 60 (0 to 300/move_dist)
            kick --> 0 (don't kick) or 1 (kick)
            continue --> 0 (don't continue) or 1 (continue)
        )

        return:
        x --> 0 to 600 (x coordinate)
        y --> 0 to 400 (y coordinate)

        # Ball relative conditions
        ball_flag --> 0 (not seen) or 1 (seen)
        ball_theta --> 0 to 360/angle_increment
        ball_dist --> 0 to 600/move_dist

        # Own goal relative conditions
        own_goal_theta --> 0 to 360/angle_increment
        own_goal_dist --> 0 to 600/move_dist

        # Opponent goal conditions
        opp_goal_theta --> 0 to 360/angle_increment
        opp_goal_dist --> 0 to 600/move_dist

        # Kick results given 0 or 1 for only one frame
        is_kick_success --> 0 (null) or 2 (miss) or 1 (hit)
        is_kick_accurate --> 0 (null) or 2 (bad miss) or 1 (near miss)

        # State flags
        is_kicking --> 0 (not kicking) or 1 (is kicking)
        is_moving --> 0 (not moving) or 1 (is moving)
        is_ball_moved -- > 0 (not moved recently) or 1 (moved recently)
        is_goal_scored --> 2 (own goal scored) 0 (not scored) or 1 (scored)

        time --> time since start (calculated based on frames)
        
        X = 0
        Y = 1
        BALL_FLAG = 2
        BALL_THETA = 3
        BALL_DIST = 4
        OWN_GOAL_THETA = 5
        OWN_GOAL_DIST = 6
        OPP_GOAL_THETA = 7
        OPP_GOAL_DIST = 8
        IS_KICK_SUCCESS = 9
        IS_KICK_ACCURATE = 10
        IS_KICKING = 11
        IS_MOVING = 12
        IS_BALL_MOVED = 13
        IS_GOAL_SCORED = 14
        TIME = 15
        ACT_DIR = 16
        ACT_THETA = 17
        ACT_DIST = 18
        ACT_KICK = 19
        ACT_CONT = 20
        """
        self.angle_increment = 15
        selt.move_dist = 5
        
        self.is_ball_detected = False
        
        self.sim = sim_master.SimMaster()
        self.states = sim.frame_step(np.array([0,0,0,0,0]))
        
        # Actions we can take
        self.action_space = gym.spaces.Dict({
            "direction": gym.spaces.Discrete(2),
            "angle": gym.spaces.Discrete((self.angle_increment))+1)),
            "distance": gym.spaces.Discrete((600/(self.move_dist))+1),
            "kick": gym.spaces.Discrete(2),
            "continue": gym.spaces.Discrete(2)       
        })
        # Observed states
        self.observation_space = gym.spaces.Dict({
            "x": gym.spaces.Discrete(601), #--> 0 to 600 (x coordinate)
            "y": gym.spaces.Discrete(401), #--> 0 to 400 (y coordinate)

            # Ball relative conditions
            "ball_flag": gym.spaces.Discrete(2), #--> 0 (not seen) or 1 (seen)
            "ball_theta": gym.spaces.Discrete((360/(self.angle_increment))+1) #--> 0 to 360/angle_increment
            "ball_dist": gym.spaces.Discrete((600/(self.move_dist))+1) #--> 0 to 600/move_dist

            # Own goal relative conditions
            "own_goal_theta": gym.spaces.Discrete((360/(self.angle_increment))+1) #--> 0 to 360/angle_increment
            "own_goal_dist": gym.spaces.Discrete((600/(self.move_dist))+1) #--> 0 to 600/move_dist

            # Opponent goal conditions
            "opp_goal_theta": gym.spaces.Discrete((360/(self.angle_increment))+1) #--> 0 to 360/angle_increment
            "opp_goal_dist": gym.spaces.Discrete((600/(self.move_dist))+1) #--> 0 to 600/move_dist

            # Kick results given 0 or 1 for only one frame
            "is_kick_success": gym.spaces.Discrete(3) #--> 0 (null) or 2 (miss) or 1 (hit)
            "is_kick_accurate": gym.spaces.Discrete(3) #--> 0 (null) or 2 (bad miss) or 1 (near miss)

            # State flags
            "is_kicking": gym.spaces.Discrete(2) #--> 0 (not kicking) or 1 (is kicking)
            "is_moving": gym.spaces.Discrete(2) #--> 0 (not moving) or 1 (is moving)
            "is_ball_moved": gym.spaces.Discrete(2) #-- > 0 (not moved recently) or 1 (moved recently)
            "is_goal_scored": gym.spaces.Discrete(3) #--> 2 (own goal scored) 0 (not scored) or 1 (scored)
            
            
        })
        
        # Set start temp
        self.state = 
        # Set shower length
        self.game_length = 2400
        
    def step(self, action):
        # Apply action
        self.states = self.sim.frame_step(action)
        
        # Calculate reward
        reward, done = calc_reward(self.states, self.is_ball_detected)
        
#         # Apply action
#         # 0 -1 = -1 temperature
#         # 1 -1 = 0 
#         # 2 -1 = 1 temperature 
#         self.state += action -1 
#         # Reduce shower length by 1 second
#         self.shower_length -= 1 
        
#         # Calculate reward
#         if self.state >=37 and self.state <=39: 
#             reward =1 
#         else: 
#             reward = -1 
        
#         # Check if shower is done
#         if self.shower_length <= 0: 
#             done = True
#         else:
#             done = False
        
#         # Apply temperature noise
#         #self.state += random.randint(-1,1)
#         # Set placeholder for info
#         info = {}
        
#         # Return step information
#         return self.state, reward, done, info

    def render(self):
        # Implement viz
        pass
    
    def reset(self):
        # Reset shower temperature
        self.state = 38 + random.randint(-3,3)
        # Reset shower time
        self.shower_length = 60 
        return self.state
    
    def calc_reward(self, current_state, is_ball_detected):
      """
      Function is called at each step
      """
      reward=0
      penalty=0

      # Ball detected (bool is_ball_detected is environment attribute)
      if not self.is_ball_detected:
        if ball_flag:
          reward+=5.0
          is_ball_detected = True

      # Ball currently in sight (assuming 2*4*15 = 120 degree field of view)
      if ball_theta <= 4*(360/self.angle_increment):
        reward+=0.01

      # Opp goal currently in sight (assuming 2*4*15 = 120 degree field of view)
      if op_goal_theta <= 4*(360/self.angle_increment):
        reward+=0.01

      # Within kicking zone of ball
      if ball_dist <= 5*(600/self.move_dist) and ball_dist >= 2*(600/move_dist):
        reward+=0.1

      # Line up directly with ball
      if ball_theta <= 1*(360/self.angle_increment):
        reward+=0.1

      # Line up directly with ball and goal
      if ball_theta <= 1*(360/self.angle_increment):
        reward+=0.5

      # Kicked ball successfully
      if is_kick_success !=0:
        if is_kick_success ==1:
          reward+=2.0
        else:
          penalty+=0.5

      # How accurate was missed kick
      if is_kick_accurate !=0:
        if is_kick_accurate == 1:
          reward+=5.0
        else:
          penalty+=0.5

      # Goal scored
      if goal_scored:
        reward+=100

      # Own goal scored
      if own_goal_scored:
        penalty+=100

      # Continuing motion
      if is_moving and is_continuing:
        reward+=0.01
      elif is_continuing # not moving but is continuing
        penalty+=0.1

      # Time penalty
      penalty+=0.01

      reward = reward - penalty

      return reward

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# states = env.observation_space.shape
# actions = env.action_space.n

# %%
def build_model(states, actions):
    model = Sequential()    
    model.add(Dense(24, activation='relu', input_shape=states))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(actions, activation='linear'))
    return model

# %%
model = build_model(states, actions)
